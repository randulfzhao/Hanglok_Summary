# %%
import pickle
import torch

with open('extracted.pkl', 'rb') as file:
    loaded_data = pickle.load(file)
    
joint_goals_list = loaded_data['A006'][0]

# %%
joint_goals_list = joint_goals_list.tolist()

# %%
for i in joint_goals_list:
    print(i)
# Out:
# [-1.6956335306167603, 1.4393757581710815, 0.057845354080200195, 2.5283567905426025, 3.086761474609375, 0.0]
# [-1.6957454681396484, 1.4411464929580688, 0.03209911286830902, 2.554063320159912, 3.090580701828003, 0.0]
# [-1.6943892240524292, 1.4424923658370972, 0.09666486084461212, 2.5124592781066895, 3.1272006034851074, 0.0]
# [-1.6939609050750732, 1.4425150156021118, 0.017672108486294746, 2.5682272911071777, 3.0848846435546875, 0.0]
# [-1.6962529420852661, 1.4454326629638672, 0.08654702454805374, 2.5105905532836914, 3.063824415206909, 0.0]
# [-1.6935040950775146, 1.4400709867477417, 0.04301437363028526, 2.543414831161499, 3.078659772872925, 0.0]
# [-1.696722388267517, 1.4371747970581055, 0.06062832847237587, 2.5314629077911377, 3.097376823425293, 0.0]
# [-1.6951771974563599, 1.4372183084487915, 0.08526774495840073, 2.50765061378479, 3.087735176086426, 0.0]
# [-1.6912237405776978, 1.4413046836853027, 0.11035796254873276, 2.498457908630371, 3.0940823554992676, 0.0]
# ...
